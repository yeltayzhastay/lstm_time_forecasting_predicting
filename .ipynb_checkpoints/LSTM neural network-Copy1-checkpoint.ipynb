# %% [markdown]
# # Рекуррентные нейронных сетей

# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df = pd.read_excel("Revised_Data_Turbine.xlsx")
df
# Out:
#       Index Hour_Time  Gas_fuel_fired_hours  Liquid fuel fired hours  \
# 0         0        H7                  8613                     3018
# 1         1        H8                  8614                     3018
# 2         2        H9                  8615                     3018
# 3         3       H10                  8616                     3018
# 4         4       H11                  8617                     3018
# ...     ...       ...                   ...                      ...
# 2979   2979        H2                 11400                     3374
# 2980   2980        H3                 11401                     3374
# 2981   2981        H4                 11402                     3374
# 2982   2982        H5                 11403                     3374
# 2983   2983        H6                 11404                     3374
#
#       Turbine hours  Start count  Compressor inlet air temp. (T1)  \
# 0            11678.0         925                             26.1
# 1            11679.0         925                             25.7
# 2            11680.0         925                             25.5
# 3            11681.0         925                             25.4
# 4            11683.0         925                             25.4
# ...              ...         ...                              ...
# 2979         14818.0        24.1                           1250.0
# 2980         14819.0        23.9                           1250.0
# 2981         14820.0        22.8                           1250.0
# 2982         14821.0        21.8                           1250.0
# 2983         14822.0        22.6                           1250.0
#
#       Compressor T5 average Turbine air inlet filter DP  \
# 0                     280.0                        0.99
# 1                     282.0                        0.98
# 2                     279.0                        0.97
# 3                     277.0                        0.99
# 4                     277.0                        0.99
# ...                     ...                         ...
# 2979                  545.0                        1.08
# 2980                  520.0                        1.05
# 2981                  582.0                        1.06
# 2982                  385.0                        1.05
# 2983                  382.0                        1.03
#
#      Compressor outlet air pressure (PCD)  ...  Generator excitation current  \
# 0                                     8.4  ...                           2.4
# 1                                     8.4  ...                           2.4
# 2                                     8.4  ...                           2.4
# 3                                     8.4  ...                           2.4
# 4                                     8.4  ...                           2.4
# ...                                   ...  ...                           ...
# 2979                                  9.8  ...                           3.9
# 2980                                  9.7  ...                           3.7
# 2981                                  9.8  ...                           3.9
# 2982                                    9  ...                             3
# 2983                                    9  ...                             3
#
#       Generator L1 winding temperature  Generator L2 winding temperature  \
# 0                                 49.0                                50
# 1                                 48.0                                49
# 2                                 47.0                                48
# 3                                 47.0                                48
# 4                                 47.0                                48
# ...                                ...                               ...
# 2979                              67.0                                68
# 2980                              65.0                                66
# 2981                              65.0                                66
# 2982                              62.0                                63
# 2983                              63.0                                64
#
#       Generator L3 winding temperature  Instrument Air Pressure  \
# 0                                 50.0                     6.14
# 1                                 49.0                     6.19
# 2                                 48.0                     6.21
# 3                                 48.0                     6.22
# 4                                 48.0                     6.22
# ...                                ...                      ...
# 2979                              68.0                     6.58
# 2980                              66.0                     6.63
# 2981                              66.0                     6.59
# 2982                              63.0                     6.59
# 2983                              54.0                     6.54
#
#       Enclosure Main Filter DP  Turbine Air Inlet Filter DP2  \
# 0                          0.8                             1
# 1                          0.8                          0.97
# 2                         0.79                          0.98
# 3                         0.79                             1
# 4                         0.79                             1
# ...                        ...                           ...
# 2979                      0.46                          1.08
# 2980                      0.47                          1.06
# 2981                      0.47                          1.06
# 2982                      0.47                          1.06
# 2983                      0.47                          1.02
#
#       Turbine Air Inlet Pre Filter DP  Turbine Air Inlet PrePre Filter DP  \
# 0                                0.92                                0.26
# 1                                0.91                                0.25
# 2                                0.91                                0.26
# 3                                0.93                                0.27
# 4                                0.93                                0.27
# ...                               ...                                 ...
# 2979                             1.13                                 0.8
# 2980                             1.13                                0.64
# 2981                             1.13                                0.77
# 2982                             1.13                                0.79
# 2983                             1.13                                0.76
#
#      Gas Fuel Control Temperature
# 0                              38
# 1                              37
# 2                              35
# 3                              35
# 4                              35
# ...                           ...
# 2979                           31
# 2980                           31
# 2981                           30
# 2982                           30
# 2983                           29
#
# [2984 rows x 52 columns]

# %%
n = 0
k = None
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False
uni_data = df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[['Turbine_vibration_2X']][n:k]
uni_data.index = list(df.index.values[n:k])
uni_data.head()
uni_data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000198758F3898>],
#       dtype=object)

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)

# %%
TRAIN_SPLIT = 2000
tf.random.set_seed(1)

# %%
uni_data = df['Turbine_vibration_2X']
uni_data.index = df.index
uni_data.head()
# Out:
# 0    15
# 1    14
# 2    15
# 3    15
# 4    15
# Name: Turbine_vibration_2X, dtype: int64

# %%
uni_data = uni_data.values

# %% [raw]
# uni_train_mean = uni_data[:TRAIN_SPLIT].mean()
# uni_train_std = uni_data[:TRAIN_SPLIT].std()
# uni_data = (uni_data-uni_train_mean)/uni_train_std

# %%
uni_data = tf.keras.utils.normalize(uni_data)[0]
uni_data
# Out:
# array([0.01580318, 0.01474964, 0.01580318, ..., 0.02107091, 0.02001736,
#        0.02001736])

# %%
def create_time_steps(length):
  return list(range(-length, 0))
def show_plot(plot_data, delta, title):
  labels = ['History', 'True Future', 'Model Prediction']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

  plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %% [markdown]
# # LSTM-модель для прогнозирование

# %% [markdown]
# # Multidemensial

# %%
features_considered = ['Turbine_vibration_2X',
       'Turbine_vibration_2Y']

# %%
features = df[features_considered]
#features.index = df['Date Time']
features.head()
# Out:
#    Turbine_vibration_2X  Turbine_vibration_2Y
# 0                    15                     9
# 1                    14                     9
# 2                    15                    10
# 3                    15                    10
# 4                    15                    10

# %%
features.max()
# Out:
# Turbine_vibration_2X    33
# Turbine_vibration_2Y    33
# dtype: int64

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std

# %% [raw]
# (dataset-data_mean)/data_std

# %% [raw]
# dataset = tf.keras.utils.normalize(features.values[:TRAIN_SPLIT])
# dataset

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
past_history = 20
future_target = 0
STEP = 1

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 0], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 0],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
x_train_single.shape
# Out:
# (1980, 20, 2)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (20, 2)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 100
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(24, input_shape=x_train_single.shape[-2:]))
#single_step_model.add(tf.keras.layers.Dense(128))
single_step_model.add(tf.keras.layers.Dense(1, activation='linear'))

single_step_model.compile(optimizer='adam', loss='mse')

# %%
for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)
# Out:
# (64, 1)

# %% [markdown]
# 100

# %%
EVALUATION_INTERVAL = 200
single_step_history = single_step_model.fit(train_data_single, epochs=50,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=200)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 3s 17ms/step - loss: 0.4844 - val_loss: 0.3508
# Epoch 2/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.3544 - val_loss: 0.2927
# Epoch 3/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.3244 - val_loss: 0.2892
# Epoch 4/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.3234 - val_loss: 0.2953
# Epoch 5/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.3115 - val_loss: 0.2972
# Epoch 6/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.3117 - val_loss: 0.3034
# Epoch 7/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.3057 - val_loss: 0.3068
# Epoch 8/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.3025 - val_loss: 0.3114
# Epoch 9/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2948 - val_loss: 0.3145
# Epoch 10/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2878 - val_loss: 0.3182
# Epoch 11/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2845 - val_loss: 0.3249
# Epoch 12/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2775 - val_loss: 0.3264
# Epoch 13/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2736 - val_loss: 0.3339
# Epoch 14/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2641 - val_loss: 0.3365
# Epoch 15/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2627 - val_loss: 0.3329
# Epoch 16/50
# 200/200 [==============================] - 3s 16ms/step - loss: 0.2549 - val_loss: 0.3310
# Epoch 17/50
# 200/200 [==============================] - 4s 18ms/step - loss: 0.2584 - val_loss: 0.3434
# Epoch 18/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.2462 - val_loss: 0.3530
# Epoch 19/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2416 - val_loss: 0.3518
# Epoch 20/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2369 - val_loss: 0.3634
# Epoch 21/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2312 - val_loss: 0.3591
# Epoch 22/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2292 - val_loss: 0.3523
# Epoch 23/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2255 - val_loss: 0.3720
# Epoch 24/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.2182 - val_loss: 0.3849
# Epoch 25/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2142 - val_loss: 0.3868
# Epoch 26/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.2088 - val_loss: 0.3870
# Epoch 27/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2054 - val_loss: 0.3979
# Epoch 28/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.2018 - val_loss: 0.3986
# Epoch 29/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1949 - val_loss: 0.4073
# Epoch 30/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1924 - val_loss: 0.4225
# Epoch 31/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1887 - val_loss: 0.4335
# Epoch 32/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1885 - val_loss: 0.4308
# Epoch 33/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1784 - val_loss: 0.4620
# Epoch 34/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1777 - val_loss: 0.4545
# Epoch 35/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1794 - val_loss: 0.4607
# Epoch 36/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1743 - val_loss: 0.4694
# Epoch 37/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1656 - val_loss: 0.4793
# Epoch 38/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1668 - val_loss: 0.5036
# Epoch 39/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1591 - val_loss: 0.5187
# Epoch 40/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1585 - val_loss: 0.5442
# Epoch 41/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1576 - val_loss: 0.5218
# Epoch 42/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1571 - val_loss: 0.5189
# Epoch 43/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1467 - val_loss: 0.5559
# Epoch 44/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1424 - val_loss: 0.5727
# Epoch 45/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1457 - val_loss: 0.5671
# Epoch 46/50
# 200/200 [==============================] - 3s 16ms/step - loss: 0.1395 - val_loss: 0.5884
# Epoch 47/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1368 - val_loss: 0.5844
# Epoch 48/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1365 - val_loss: 0.5965
# Epoch 49/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1370 - val_loss: 0.6184
# Epoch 50/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1287 - val_loss: 0.6149

# %%
for x, y in val_data_single.take(3):
  plot = show_plot([x[0][:, 0].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 0,
                   'Single Step Prediction')
  plot.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %% [markdown]
# # TESTING

# %% [raw]
# df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[:int(len(df.Turbine_vibration_2X)*0.05)].index[:10]

# %%
for i in df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[:int(len(df.Turbine_vibration_2X)*0.05)].index[:10]:
    x_test_single, y_test_single = multivariate_data(dataset, dataset[:, 0],
                                               i-(100 + future_target), i+1, past_history,
                                               future_target, STEP,
                                               single_step=True)
    test_data_single = tf.data.Dataset.from_tensor_slices((x_test_single, y_test_single))
    test_data_single = test_data_single.batch(BATCH_SIZE).repeat()
    for x, y in test_data_single.take(1):
        plot = show_plot([x[0][:, 0].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'index: ' + str(i))
        plot.show()
