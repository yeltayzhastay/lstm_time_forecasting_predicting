# %% [markdown]
# # Рекуррентные нейронных сетей

# %%
import tensorflow as tf
from tensorflow import keras

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df = pd.read_excel("Revised_Data_Turbine.xlsx")
df
# Out:
#       Index Hour_Time  Gas_fuel_fired_hours  Liquid fuel fired hours  \
# 0         0        H7                  8613                     3018
# 1         1        H8                  8614                     3018
# 2         2        H9                  8615                     3018
# 3         3       H10                  8616                     3018
# 4         4       H11                  8617                     3018
# ...     ...       ...                   ...                      ...
# 2979   2979        H2                 11400                     3374
# 2980   2980        H3                 11401                     3374
# 2981   2981        H4                 11402                     3374
# 2982   2982        H5                 11403                     3374
# 2983   2983        H6                 11404                     3374
#
#       Turbine hours  Start count  Compressor inlet air temp. (T1)  \
# 0            11678.0         925                             26.1
# 1            11679.0         925                             25.7
# 2            11680.0         925                             25.5
# 3            11681.0         925                             25.4
# 4            11683.0         925                             25.4
# ...              ...         ...                              ...
# 2979         14818.0        24.1                           1250.0
# 2980         14819.0        23.9                           1250.0
# 2981         14820.0        22.8                           1250.0
# 2982         14821.0        21.8                           1250.0
# 2983         14822.0        22.6                           1250.0
#
#       Compressor T5 average Turbine air inlet filter DP  \
# 0                     280.0                        0.99
# 1                     282.0                        0.98
# 2                     279.0                        0.97
# 3                     277.0                        0.99
# 4                     277.0                        0.99
# ...                     ...                         ...
# 2979                  545.0                        1.08
# 2980                  520.0                        1.05
# 2981                  582.0                        1.06
# 2982                  385.0                        1.05
# 2983                  382.0                        1.03
#
#      Compressor outlet air pressure (PCD)  ...  Generator excitation current  \
# 0                                     8.4  ...                           2.4
# 1                                     8.4  ...                           2.4
# 2                                     8.4  ...                           2.4
# 3                                     8.4  ...                           2.4
# 4                                     8.4  ...                           2.4
# ...                                   ...  ...                           ...
# 2979                                  9.8  ...                           3.9
# 2980                                  9.7  ...                           3.7
# 2981                                  9.8  ...                           3.9
# 2982                                    9  ...                             3
# 2983                                    9  ...                             3
#
#       Generator L1 winding temperature  Generator L2 winding temperature  \
# 0                                 49.0                                50
# 1                                 48.0                                49
# 2                                 47.0                                48
# 3                                 47.0                                48
# 4                                 47.0                                48
# ...                                ...                               ...
# 2979                              67.0                                68
# 2980                              65.0                                66
# 2981                              65.0                                66
# 2982                              62.0                                63
# 2983                              63.0                                64
#
#       Generator L3 winding temperature  Instrument Air Pressure  \
# 0                                 50.0                     6.14
# 1                                 49.0                     6.19
# 2                                 48.0                     6.21
# 3                                 48.0                     6.22
# 4                                 48.0                     6.22
# ...                                ...                      ...
# 2979                              68.0                     6.58
# 2980                              66.0                     6.63
# 2981                              66.0                     6.59
# 2982                              63.0                     6.59
# 2983                              54.0                     6.54
#
#       Enclosure Main Filter DP  Turbine Air Inlet Filter DP2  \
# 0                          0.8                             1
# 1                          0.8                          0.97
# 2                         0.79                          0.98
# 3                         0.79                             1
# 4                         0.79                             1
# ...                        ...                           ...
# 2979                      0.46                          1.08
# 2980                      0.47                          1.06
# 2981                      0.47                          1.06
# 2982                      0.47                          1.06
# 2983                      0.47                          1.02
#
#       Turbine Air Inlet Pre Filter DP  Turbine Air Inlet PrePre Filter DP  \
# 0                                0.92                                0.26
# 1                                0.91                                0.25
# 2                                0.91                                0.26
# 3                                0.93                                0.27
# 4                                0.93                                0.27
# ...                               ...                                 ...
# 2979                             1.13                                 0.8
# 2980                             1.13                                0.64
# 2981                             1.13                                0.77
# 2982                             1.13                                0.79
# 2983                             1.13                                0.76
#
#      Gas Fuel Control Temperature
# 0                              38
# 1                              37
# 2                              35
# 3                              35
# 4                              35
# ...                           ...
# 2979                           31
# 2980                           31
# 2981                           30
# 2982                           30
# 2983                           29
#
# [2984 rows x 52 columns]

# %%
n = 0
k = None
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False
uni_data = df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[['Turbine_vibration_2X']][n:k]
uni_data.index = list(df.index.values[n:k])
uni_data.head()
uni_data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020E670FB5C0>],
#       dtype=object)

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)

# %%
TRAIN_SPLIT = 2000
tf.random.set_seed(1)

# %%
uni_data = df['Turbine_vibration_2X']
uni_data.index = df.index
uni_data.head()
# Out:
# 0    15
# 1    14
# 2    15
# 3    15
# 4    15
# Name: Turbine_vibration_2X, dtype: int64

# %%
uni_data = uni_data.values

# %% [raw]
# uni_train_mean = uni_data[:TRAIN_SPLIT].mean()
# uni_train_std = uni_data[:TRAIN_SPLIT].std()
# uni_data = (uni_data-uni_train_mean)/uni_train_std

# %%
uni_data = tf.keras.utils.normalize(uni_data)[0]
uni_data
# Out:
# array([0.01580318, 0.01474964, 0.01580318, ..., 0.02107091, 0.02001736,
#        0.02001736])

# %%
def create_time_steps(length):
  return list(range(-length, 0))
def show_plot(plot_data, delta, title):
  labels = ['History', 'True Future', 'Model Prediction']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

  plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %% [markdown]
# # LSTM-модель для прогнозирование

# %%
features_considered = ['Turbine_vibration_2X',
       'Turbine_vibration_2Y']

# %%
features = df[features_considered]
#features.index = df['Date Time']
features.head()
# Out:
#    Turbine_vibration_2X  Turbine_vibration_2Y
# 0                    15                     9
# 1                    14                     9
# 2                    15                    10
# 3                    15                    10
# 4                    15                    10

# %%
features.max()
# Out:
# Turbine_vibration_2X    33
# Turbine_vibration_2Y    33
# dtype: int64

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std

# %% [raw]
# (dataset-data_mean)/data_std

# %% [raw]
# dataset = tf.keras.utils.normalize(features.values[:TRAIN_SPLIT])
# dataset

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %% [markdown]
# # Multidemensial

# %%
past_history = 100
future_target = 3
STEP = 1

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 0], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 0],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
x_train_single.shape
# Out:
# (1900, 100, 2)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (100, 2)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 100
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(64, input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(128))
single_step_model.add(tf.keras.layers.Dense(1, activation='linear'))

single_step_model.compile(optimizer='adam', loss='mse')

# %%
for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)
# Out:
# (64, 1)

# %% [markdown]
# 100

# %%
EVALUATION_INTERVAL = 200
single_step_history = single_step_model.fit(train_data_single, epochs=100,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=200)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 16s 78ms/step - loss: 0.5923 - val_loss: 0.4675
# Epoch 2/100
# 200/200 [==============================] - 16s 81ms/step - loss: 0.4976 - val_loss: 0.4747
# Epoch 3/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.4664 - val_loss: 0.4913
# Epoch 4/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.4199 - val_loss: 0.5186
# Epoch 5/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.3788 - val_loss: 0.5444
# Epoch 6/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.3588 - val_loss: 0.7037
# Epoch 7/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.3244 - val_loss: 0.5623
# Epoch 8/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2807 - val_loss: 0.6140
# Epoch 9/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2778 - val_loss: 0.6214
# Epoch 10/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2598 - val_loss: 0.6411
# Epoch 11/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2343 - val_loss: 0.5806
# Epoch 12/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2327 - val_loss: 0.6123
# Epoch 13/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2116 - val_loss: 0.7498
# Epoch 14/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2111 - val_loss: 0.6459
# Epoch 15/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1876 - val_loss: 0.6524
# Epoch 16/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.1645 - val_loss: 0.6956
# Epoch 17/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1907 - val_loss: 0.6521
# Epoch 18/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1627 - val_loss: 0.7099
# Epoch 19/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1466 - val_loss: 0.7186
# Epoch 20/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1287 - val_loss: 0.7153
# Epoch 21/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1665 - val_loss: 0.6815
# Epoch 22/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.1485 - val_loss: 0.7045
# Epoch 23/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.1279 - val_loss: 0.6985
# Epoch 24/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.1189 - val_loss: 0.7040
# Epoch 25/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1227 - val_loss: 0.7038
# Epoch 26/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1257 - val_loss: 0.6613
# Epoch 27/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1169 - val_loss: 0.6784
# Epoch 28/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.1025 - val_loss: 0.7029
# Epoch 29/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.1130 - val_loss: 0.7021
# Epoch 30/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1073 - val_loss: 0.7114
# Epoch 31/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.0991 - val_loss: 0.7204
# Epoch 32/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0897 - val_loss: 0.7051
# Epoch 33/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1844 - val_loss: 0.6130
# Epoch 34/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1086 - val_loss: 0.6547
# Epoch 35/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0858 - val_loss: 0.6603
# Epoch 36/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0889 - val_loss: 0.6898
# Epoch 37/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0643 - val_loss: 0.7193
# Epoch 38/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0833 - val_loss: 0.6889
# Epoch 39/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0680 - val_loss: 0.7153
# Epoch 40/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0565 - val_loss: 0.7216
# Epoch 41/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0670 - val_loss: 0.7198
# Epoch 42/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0725 - val_loss: 0.7330
# Epoch 43/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0608 - val_loss: 0.7454
# Epoch 44/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0438 - val_loss: 0.7375
# Epoch 45/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0457 - val_loss: 0.7215
# Epoch 46/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0504 - val_loss: 0.7225
# Epoch 47/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1004 - val_loss: 0.7390
# Epoch 48/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0492 - val_loss: 0.7300
# Epoch 49/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0525 - val_loss: 0.7551
# Epoch 50/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0319 - val_loss: 0.7662
# Epoch 51/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0406 - val_loss: 0.7278
# Epoch 52/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0385 - val_loss: 0.7660
# Epoch 53/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0283 - val_loss: 0.7339
# Epoch 54/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0679 - val_loss: 0.6965
# Epoch 55/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0355 - val_loss: 0.7207
# Epoch 56/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0493 - val_loss: 0.6950
# Epoch 57/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0259 - val_loss: 0.7021
# Epoch 58/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0252 - val_loss: 0.7054
# Epoch 59/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.0287 - val_loss: 0.6989
# Epoch 60/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.0222 - val_loss: 0.7119
# Epoch 61/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.0264 - val_loss: 0.7283
# Epoch 62/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.0343 - val_loss: 0.6777
# Epoch 63/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0607 - val_loss: 0.6760
# Epoch 64/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0289 - val_loss: 0.6821
# Epoch 65/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0128 - val_loss: 0.6899
# Epoch 66/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0134 - val_loss: 0.6721
# Epoch 67/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0149 - val_loss: 0.7030
# Epoch 68/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0213 - val_loss: 0.6663
# Epoch 69/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.1028 - val_loss: 0.6533
# Epoch 70/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.1726 - val_loss: 0.6489
# Epoch 71/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0716 - val_loss: 0.7040
# Epoch 72/100
# 200/200 [==============================] - 19s 93ms/step - loss: 0.0390 - val_loss: 0.7232
# Epoch 73/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.0285 - val_loss: 0.7058
# Epoch 74/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.0371 - val_loss: 0.6826
# Epoch 75/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0239 - val_loss: 0.7028
# Epoch 76/100
# 200/200 [==============================] - 18s 88ms/step - loss: 0.0195 - val_loss: 0.7072
# Epoch 77/100
# 200/200 [==============================] - 18s 88ms/step - loss: 0.0179 - val_loss: 0.7244
# Epoch 78/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.0156 - val_loss: 0.7047
# Epoch 79/100
# 200/200 [==============================] - 18s 88ms/step - loss: 0.0181 - val_loss: 0.6979
# Epoch 80/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.0224 - val_loss: 0.6882
# Epoch 81/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0145 - val_loss: 0.7201
# Epoch 82/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0188 - val_loss: 0.6706
# Epoch 83/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0205 - val_loss: 0.7144
# Epoch 84/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0257 - val_loss: 0.7087
# Epoch 85/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0154 - val_loss: 0.6934
# Epoch 86/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0186 - val_loss: 0.6873
# Epoch 87/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.0237 - val_loss: 0.6973
# Epoch 88/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0221 - val_loss: 0.6671
# Epoch 89/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0162 - val_loss: 0.6806
# Epoch 90/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0138 - val_loss: 0.6906
# Epoch 91/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0147 - val_loss: 0.6968
# Epoch 92/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0134 - val_loss: 0.6933
# Epoch 93/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.0341 - val_loss: 0.6647
# Epoch 94/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.0176 - val_loss: 0.6885
# Epoch 95/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.0096 - val_loss: 0.6901
# Epoch 96/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.0113 - val_loss: 0.6898
# Epoch 97/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.0219 - val_loss: 0.6682
# Epoch 98/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.0208 - val_loss: 0.6847
# Epoch 99/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0103 - val_loss: 0.6919
# Epoch 100/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0042 - val_loss: 0.6865

# %%
for x, y in val_data_single.take(3):
  plot = show_plot([x[0][:, 0].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 1,
                   'Single Step Prediction')
  plot.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %% [markdown]
# # Interval

# %%
past_history = 100
future_target = 6
STEP = 1
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 None, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (6,)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 100

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(24, 12))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()

# %%
for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(64, return_sequences=True, input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(128, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(6))

multi_step_model.compile(optimizer='adam', loss='mse')

# %%
for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)
# Out:
# (64, 6)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=50,
                                          steps_per_epoch=200,
                                          validation_data=val_data_multi,
                                          validation_steps=200)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 29s 143ms/step - loss: 0.9006 - val_loss: 0.7692
# Epoch 2/50
# 200/200 [==============================] - 31s 153ms/step - loss: 0.7847 - val_loss: 0.6744
# Epoch 3/50
# 200/200 [==============================] - 32s 158ms/step - loss: 0.7236 - val_loss: 0.6259
# Epoch 4/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.6561 - val_loss: 0.6155
# Epoch 5/50
# 200/200 [==============================] - 29s 147ms/step - loss: 0.6545 - val_loss: 0.5792
# Epoch 6/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.6401 - val_loss: 0.5798
# Epoch 7/50
# 200/200 [==============================] - 31s 155ms/step - loss: 0.5956 - val_loss: 0.5502
# Epoch 8/50
# 200/200 [==============================] - 32s 162ms/step - loss: 0.5999 - val_loss: 0.5438
# Epoch 9/50
# 200/200 [==============================] - 31s 155ms/step - loss: 0.5636 - val_loss: 0.5427
# Epoch 10/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.5496 - val_loss: 0.5321
# Epoch 11/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.5325 - val_loss: 0.5085
# Epoch 12/50
# 200/200 [==============================] - 31s 154ms/step - loss: 0.5147 - val_loss: 0.5126
# Epoch 13/50
# 200/200 [==============================] - 30s 151ms/step - loss: 0.4834 - val_loss: 0.5035
# Epoch 14/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.4828 - val_loss: 0.4680
# Epoch 15/50
# 200/200 [==============================] - 29s 147ms/step - loss: 0.4641 - val_loss: 0.5524
# Epoch 16/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.4694 - val_loss: 0.4531
# Epoch 17/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.4371 - val_loss: 0.5079
# Epoch 18/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.4230 - val_loss: 0.4119
# Epoch 19/50
# 200/200 [==============================] - 31s 153ms/step - loss: 0.4309 - val_loss: 0.4450
# Epoch 20/50
# 200/200 [==============================] - 31s 153ms/step - loss: 0.4031 - val_loss: 0.4362
# Epoch 21/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.4555 - val_loss: 0.4528
# Epoch 22/50
# 200/200 [==============================] - 30s 151ms/step - loss: 0.3905 - val_loss: 0.3736
# Epoch 23/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.3712 - val_loss: 0.3626
# Epoch 24/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.3400 - val_loss: 0.3631
# Epoch 25/50
# 200/200 [==============================] - 29s 147ms/step - loss: 0.3440 - val_loss: 0.3645
# Epoch 26/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.3255 - val_loss: 0.3100
# Epoch 27/50
# 200/200 [==============================] - 30s 151ms/step - loss: 0.3674 - val_loss: 0.4712
# Epoch 28/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.3824 - val_loss: 0.3185
# Epoch 29/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.2990 - val_loss: 0.2578
# Epoch 30/50
# 200/200 [==============================] - 30s 152ms/step - loss: 0.2795 - val_loss: 0.2677
# Epoch 31/50
# 200/200 [==============================] - 29s 147ms/step - loss: 0.2602 - val_loss: 0.2687
# Epoch 32/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.2910 - val_loss: 0.2789
# Epoch 33/50
# 200/200 [==============================] - 30s 151ms/step - loss: 0.2633 - val_loss: 0.3141
# Epoch 34/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.2867 - val_loss: 0.2436
# Epoch 35/50
# 200/200 [==============================] - 29s 147ms/step - loss: 0.2605 - val_loss: 0.2674
# Epoch 36/50
# 200/200 [==============================] - 29s 147ms/step - loss: 0.2721 - val_loss: 0.3102
# Epoch 37/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.2595 - val_loss: 0.2540
# Epoch 38/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.2213 - val_loss: 0.2103
# Epoch 39/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.2134 - val_loss: 0.2282
# Epoch 40/50
# 200/200 [==============================] - 30s 151ms/step - loss: 0.2165 - val_loss: 0.2557
# Epoch 41/50
# 200/200 [==============================] - 31s 156ms/step - loss: 0.2435 - val_loss: 0.2299
# Epoch 42/50
# 200/200 [==============================] - 32s 161ms/step - loss: 0.2012 - val_loss: 0.2120
# Epoch 43/50
# 200/200 [==============================] - 36s 180ms/step - loss: 0.2242 - val_loss: 0.2315
# Epoch 44/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.2833 - val_loss: 0.2762
# Epoch 45/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.2445 - val_loss: 0.1989
# Epoch 46/50
# 200/200 [==============================] - 30s 150ms/step - loss: 0.1980 - val_loss: 0.2054
# Epoch 47/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.1967 - val_loss: 0.2125
# Epoch 48/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.2038 - val_loss: 0.2001
# Epoch 49/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.1830 - val_loss: 0.2002
# Epoch 50/50
# 200/200 [==============================] - 30s 149ms/step - loss: 0.1940 - val_loss: 0.1975

# %% [raw]
# multi_step_history.history['loss'][20] = 0.502015752526533

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %% [raw]
# multi_step_model.save('interval')

# %%
multi_step_model = keras.models.load_model("interval")

# %%
for x, y in val_data_multi.take(3):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])

# %% [markdown]
# # TESTING

# %% [raw]
# df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[:int(len(df.Turbine_vibration_2X)*0.05)].index[:10]

# %%
for i in df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[:int(len(df.Turbine_vibration_2X)*0.05)].index[:10]:
    x_test_single, y_test_single = multivariate_data(dataset, dataset[:, 1],
                                               i-100, i + future_target + 1, past_history,
                                               future_target, STEP)
    
    test_data_single = tf.data.Dataset.from_tensor_slices((x_test_single, y_test_single))
    test_data_single = test_data_single.batch(BATCH_SIZE).repeat()
    
    for x, y in test_data_single.take(1):
        multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
