# %% [markdown]
# # Рекуррентные нейронных сетей

# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df = pd.read_excel("Revised_Data_Turbine.xlsx")
df
# Out:
#       Index Hour_Time  Gas_fuel_fired_hours  Liquid fuel fired hours  \
# 0         0        H7                  8613                     3018
# 1         1        H8                  8614                     3018
# 2         2        H9                  8615                     3018
# 3         3       H10                  8616                     3018
# 4         4       H11                  8617                     3018
# ...     ...       ...                   ...                      ...
# 2979   2979        H2                 11400                     3374
# 2980   2980        H3                 11401                     3374
# 2981   2981        H4                 11402                     3374
# 2982   2982        H5                 11403                     3374
# 2983   2983        H6                 11404                     3374
#
#       Turbine hours  Start count  Compressor inlet air temp. (T1)  \
# 0            11678.0         925                             26.1
# 1            11679.0         925                             25.7
# 2            11680.0         925                             25.5
# 3            11681.0         925                             25.4
# 4            11683.0         925                             25.4
# ...              ...         ...                              ...
# 2979         14818.0        24.1                           1250.0
# 2980         14819.0        23.9                           1250.0
# 2981         14820.0        22.8                           1250.0
# 2982         14821.0        21.8                           1250.0
# 2983         14822.0        22.6                           1250.0
#
#       Compressor T5 average Turbine air inlet filter DP  \
# 0                     280.0                        0.99
# 1                     282.0                        0.98
# 2                     279.0                        0.97
# 3                     277.0                        0.99
# 4                     277.0                        0.99
# ...                     ...                         ...
# 2979                  545.0                        1.08
# 2980                  520.0                        1.05
# 2981                  582.0                        1.06
# 2982                  385.0                        1.05
# 2983                  382.0                        1.03
#
#      Compressor outlet air pressure (PCD)  ...  Generator excitation current  \
# 0                                     8.4  ...                           2.4
# 1                                     8.4  ...                           2.4
# 2                                     8.4  ...                           2.4
# 3                                     8.4  ...                           2.4
# 4                                     8.4  ...                           2.4
# ...                                   ...  ...                           ...
# 2979                                  9.8  ...                           3.9
# 2980                                  9.7  ...                           3.7
# 2981                                  9.8  ...                           3.9
# 2982                                    9  ...                             3
# 2983                                    9  ...                             3
#
#       Generator L1 winding temperature  Generator L2 winding temperature  \
# 0                                 49.0                                50
# 1                                 48.0                                49
# 2                                 47.0                                48
# 3                                 47.0                                48
# 4                                 47.0                                48
# ...                                ...                               ...
# 2979                              67.0                                68
# 2980                              65.0                                66
# 2981                              65.0                                66
# 2982                              62.0                                63
# 2983                              63.0                                64
#
#       Generator L3 winding temperature  Instrument Air Pressure  \
# 0                                 50.0                     6.14
# 1                                 49.0                     6.19
# 2                                 48.0                     6.21
# 3                                 48.0                     6.22
# 4                                 48.0                     6.22
# ...                                ...                      ...
# 2979                              68.0                     6.58
# 2980                              66.0                     6.63
# 2981                              66.0                     6.59
# 2982                              63.0                     6.59
# 2983                              54.0                     6.54
#
#       Enclosure Main Filter DP  Turbine Air Inlet Filter DP2  \
# 0                          0.8                             1
# 1                          0.8                          0.97
# 2                         0.79                          0.98
# 3                         0.79                             1
# 4                         0.79                             1
# ...                        ...                           ...
# 2979                      0.46                          1.08
# 2980                      0.47                          1.06
# 2981                      0.47                          1.06
# 2982                      0.47                          1.06
# 2983                      0.47                          1.02
#
#       Turbine Air Inlet Pre Filter DP  Turbine Air Inlet PrePre Filter DP  \
# 0                                0.92                                0.26
# 1                                0.91                                0.25
# 2                                0.91                                0.26
# 3                                0.93                                0.27
# 4                                0.93                                0.27
# ...                               ...                                 ...
# 2979                             1.13                                 0.8
# 2980                             1.13                                0.64
# 2981                             1.13                                0.77
# 2982                             1.13                                0.79
# 2983                             1.13                                0.76
#
#      Gas Fuel Control Temperature
# 0                              38
# 1                              37
# 2                              35
# 3                              35
# 4                              35
# ...                           ...
# 2979                           31
# 2980                           31
# 2981                           30
# 2982                           30
# 2983                           29
#
# [2984 rows x 52 columns]

# %%
n = 0
k = None
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False
uni_data = df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[['Turbine_vibration_2X']][n:k]
uni_data.index = list(df.index.values[n:k])
uni_data.head()
uni_data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002962F104C88>],
#       dtype=object)

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)

# %%
TRAIN_SPLIT = 2000
tf.random.set_seed(1)

# %%
uni_data = df['Turbine_vibration_2X']
uni_data.index = df.index
uni_data.head()
# Out:
# 0    15
# 1    14
# 2    15
# 3    15
# 4    15
# Name: Turbine_vibration_2X, dtype: int64

# %%
uni_data = uni_data.values

# %% [raw]
# uni_train_mean = uni_data[:TRAIN_SPLIT].mean()
# uni_train_std = uni_data[:TRAIN_SPLIT].std()
# uni_data = (uni_data-uni_train_mean)/uni_train_std

# %%
uni_data = tf.keras.utils.normalize(uni_data)[0]
uni_data
# Out:
# array([0.01580318, 0.01474964, 0.01580318, ..., 0.02107091, 0.02001736,
#        0.02001736])

# %%
def create_time_steps(length):
  return list(range(-length, 0))
def show_plot(plot_data, delta, title):
  labels = ['History', 'True Future', 'Model Prediction']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

  plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %% [markdown]
# # LSTM-модель для прогнозирование

# %% [markdown]
# # Multidemensial

# %%
features_considered = ['Turbine_vibration_2X',
       'Turbine_vibration_2Y']

# %%
features = df[features_considered]
#features.index = df['Date Time']
features.head()
# Out:
#    Turbine_vibration_2X  Turbine_vibration_2Y
# 0                    15                     9
# 1                    14                     9
# 2                    15                    10
# 3                    15                    10
# 4                    15                    10

# %%
features.max()
# Out:
# Turbine_vibration_2X    33
# Turbine_vibration_2Y    33
# dtype: int64

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std

# %% [raw]
# (dataset-data_mean)/data_std

# %% [raw]
# dataset = tf.keras.utils.normalize(features.values[:TRAIN_SPLIT])
# dataset

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
past_history = 50
future_target = 0
STEP = 1

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 0], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 0],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
x_train_single.shape
# Out:
# (1950, 50, 2)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (50, 2)

# %%
BATCH_SIZE = 128
BUFFER_SIZE = 500
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(48))
single_step_model.add(tf.keras.layers.Dense(1, activation='linear'))

single_step_model.compile(optimizer='adam', loss='mae')

# %%
for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)
# Out:
# (128, 1)

# %% [markdown]
# 100

# %%
EVALUATION_INTERVAL = 200
single_step_history = single_step_model.fit(train_data_single, epochs=100,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=200)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4515 - val_loss: 0.3866
# Epoch 2/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3845 - val_loss: 0.3757
# Epoch 3/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3786 - val_loss: 0.3758
# Epoch 4/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3774 - val_loss: 0.3793
# Epoch 5/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3732 - val_loss: 0.3780
# Epoch 6/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3667 - val_loss: 0.3824
# Epoch 7/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3585 - val_loss: 0.3888
# Epoch 8/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3538 - val_loss: 0.3874
# Epoch 9/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3491 - val_loss: 0.3922
# Epoch 10/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3444 - val_loss: 0.3975
# Epoch 11/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3374 - val_loss: 0.4003
# Epoch 12/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3340 - val_loss: 0.3990
# Epoch 13/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3280 - val_loss: 0.4061
# Epoch 14/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.3278 - val_loss: 0.4207
# Epoch 15/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3227 - val_loss: 0.4152
# Epoch 16/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3170 - val_loss: 0.4349
# Epoch 17/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3120 - val_loss: 0.4412
# Epoch 18/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.3104 - val_loss: 0.4494
# Epoch 19/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3052 - val_loss: 0.4505
# Epoch 20/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2989 - val_loss: 0.4684
# Epoch 21/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.2975 - val_loss: 0.4806
# Epoch 22/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.2920 - val_loss: 0.4891
# Epoch 23/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.2881 - val_loss: 0.4958
# Epoch 24/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.2812 - val_loss: 0.5123
# Epoch 25/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.2781 - val_loss: 0.5266
# Epoch 26/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.2797 - val_loss: 0.5288
# Epoch 27/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2737 - val_loss: 0.5243
# Epoch 28/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.2674 - val_loss: 0.5455
# Epoch 29/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.2662 - val_loss: 0.5529
# Epoch 30/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.2624 - val_loss: 0.5686
# Epoch 31/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.2612 - val_loss: 0.5761
# Epoch 32/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.2568 - val_loss: 0.5760
# Epoch 33/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.2510 - val_loss: 0.5932
# Epoch 34/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.2528 - val_loss: 0.5812
# Epoch 35/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.2464 - val_loss: 0.6043
# Epoch 36/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.2450 - val_loss: 0.6265
# Epoch 37/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.2419 - val_loss: 0.6288
# Epoch 38/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2400 - val_loss: 0.6424
# Epoch 39/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2383 - val_loss: 0.6421
# Epoch 40/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2351 - val_loss: 0.6636
# Epoch 41/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2367 - val_loss: 0.6639
# Epoch 42/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2289 - val_loss: 0.6634
# Epoch 43/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2224 - val_loss: 0.6817
# Epoch 44/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2226 - val_loss: 0.6721
# Epoch 45/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2502 - val_loss: 0.6095
# Epoch 46/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2514 - val_loss: 0.6346
# Epoch 47/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.2378 - val_loss: 0.6571
# Epoch 48/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2206 - val_loss: 0.6754
# Epoch 49/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2121 - val_loss: 0.6924
# Epoch 50/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2144 - val_loss: 0.6759
# Epoch 51/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2108 - val_loss: 0.6953
# Epoch 52/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2036 - val_loss: 0.7128
# Epoch 53/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.2062 - val_loss: 0.7016
# Epoch 54/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2016 - val_loss: 0.7199
# Epoch 55/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2050 - val_loss: 0.7333
# Epoch 56/100
# 200/200 [==============================] - 8s 39ms/step - loss: 0.2011 - val_loss: 0.7254
# Epoch 57/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.1945 - val_loss: 0.7425
# Epoch 58/100
# 200/200 [==============================] - 9s 43ms/step - loss: 0.1962 - val_loss: 0.7296
# Epoch 59/100
# 200/200 [==============================] - 7s 36ms/step - loss: 0.1932 - val_loss: 0.7410
# Epoch 60/100
# 200/200 [==============================] - 7s 35ms/step - loss: 0.1914 - val_loss: 0.7442
# Epoch 61/100
# 200/200 [==============================] - 7s 34ms/step - loss: 0.1890 - val_loss: 0.7838
# Epoch 62/100
# 200/200 [==============================] - 7s 33ms/step - loss: 0.1876 - val_loss: 0.7626
# Epoch 63/100
# 200/200 [==============================] - 7s 37ms/step - loss: 0.1885 - val_loss: 0.7593
# Epoch 64/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1873 - val_loss: 0.7700
# Epoch 65/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1786 - val_loss: 0.7629
# Epoch 66/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1863 - val_loss: 0.7533
# Epoch 67/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1799 - val_loss: 0.7813
# Epoch 68/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1805 - val_loss: 0.7682
# Epoch 69/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1830 - val_loss: 0.7945
# Epoch 70/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1737 - val_loss: 0.7948
# Epoch 71/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1722 - val_loss: 0.7912
# Epoch 72/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1715 - val_loss: 0.7970
# Epoch 73/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1719 - val_loss: 0.8121
# Epoch 74/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1679 - val_loss: 0.7940
# Epoch 75/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.1665 - val_loss: 0.8184
# Epoch 76/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1686 - val_loss: 0.8145
# Epoch 77/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1674 - val_loss: 0.8107
# Epoch 78/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1618 - val_loss: 0.8293
# Epoch 79/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.1634 - val_loss: 0.8213
# Epoch 80/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.1653 - val_loss: 0.8376
# Epoch 81/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.1605 - val_loss: 0.8063
# Epoch 82/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1626 - val_loss: 0.8075
# Epoch 83/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1609 - val_loss: 0.8343
# Epoch 84/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1578 - val_loss: 0.8156
# Epoch 85/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1585 - val_loss: 0.8308
# Epoch 86/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1582 - val_loss: 0.8195
# Epoch 87/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1562 - val_loss: 0.8091
# Epoch 88/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1507 - val_loss: 0.8442
# Epoch 89/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1606 - val_loss: 0.8109
# Epoch 90/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.1561 - val_loss: 0.8252
# Epoch 91/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.1539 - val_loss: 0.8294
# Epoch 92/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1563 - val_loss: 0.8534
# Epoch 93/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1523 - val_loss: 0.8505
# Epoch 94/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1579 - val_loss: 0.8212
# Epoch 95/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1482 - val_loss: 0.8391
# Epoch 96/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1483 - val_loss: 0.8400
# Epoch 97/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.1547 - val_loss: 0.8645
# Epoch 98/100
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1494 - val_loss: 0.8436
# Epoch 99/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.1469 - val_loss: 0.8521
# Epoch 100/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.1464 - val_loss: 0.8456

# %%
for x, y in val_data_single.take(3):
  plot = show_plot([x[0][:, 0].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 0,
                   'Single Step Prediction')
  plot.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %% [markdown]
# # TESTING

# %% [raw]
# df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[:int(len(df.Turbine_vibration_2X)*0.05)].index[:10]

# %%
for i in df.sort_values(by=['Turbine_vibration_2X'], ascending=False)[:int(len(df.Turbine_vibration_2X)*0.05)].index[:10]:
    x_test_single, y_test_single = multivariate_data(dataset, dataset[:, 0],
                                               i-(100 + future_target), i+1, past_history,
                                               future_target, STEP,
                                               single_step=True)
    test_data_single = tf.data.Dataset.from_tensor_slices((x_test_single, y_test_single))
    test_data_single = test_data_single.batch(BATCH_SIZE).repeat()
    for x, y in test_data_single.take(1):
        plot = show_plot([x[0][:, 0].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'index: ' + str(i))
        plot.show()
